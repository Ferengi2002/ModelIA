# %%
# Mi primera celda
mensaje = "¡Hola bro! Mi Notebook está funcionando a la perfección."
print(mensaje)
# Out:
# ¡Hola bro! Mi Notebook está funcionando a la perfección.

# %%
# Hacemos una operación sencilla
a = 15
b = 25
resultado = a + b

print(f"La suma de {a} y {b} es: {resultado}")
# Out:
# La suma de 15 y 25 es: 40
